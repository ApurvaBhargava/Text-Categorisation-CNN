agacc3 = [63.55,72.275,79.95,84.5,85.775,86.275,86.8,86.975,87.275,87.525,87.675,87.875,88.1,88.15,88.225,88.375,88.475,88.425,88.65,88.7,88.675,88.6,89,88.85,88.875,89.1,89.1,89.075,89,88.65]
agacc4 = [62.575,72.65,78.775,82.7,84.15,85.35,85.8,86.175,86.875,86.7,86.95,87.4,87.65,87.7,87.75,87.975,88.15,88.275,88.1,88.15,88.225,88.125,88.3,88.15,88.2,88.225,88.4,88.325,88.375,88.325]
# losses
agloss1 = [1.1923659,0.8363257,0.5804125,0.46120453,0.40401986,0.3766906,0.3615553,0.3526131,0.3460384,0.33899415,0.33568034,0.33207348,0.33251265,0.32773614,0.32630628,0.3252231,0.32210296,0.32145053,0.32197452,0.320775,0.31955793,0.31786272,0.31700954,0.31796587,0.31795827,0.31688318,0.31490865,0.31563297,0.3140424,0.3157507]
agloss2 = [1.1288006,0.76297224,0.5559592,0.45928237,0.4088442,0.3830937,0.3658807,0.35626614,0.34979498,0.3423863,0.33997625,0.33449283,0.33294037,0.33100376,0.32755166,0.3263837,0.3244122,0.32282263,0.32330546,0.3213964,0.32091734,0.31878993,0.3182195,0.3166959,0.31616876,0.31582615,0.31799135,0.31553787,0.31529784,0.31460547]
agloss3 = [1.3117615,1.1506712,0.92263037,0.69554454,0.5459414,0.4718632,0.42954275,0.40480784,0.3906502,0.377375,0.37053195,0.3623844,0.35637417,0.35177094,0.34748912,0.34432665,0.34032878,0.33852702,0.33773392,0.3338686,0.33397344,0.33224073,0.32931444,0.32916978,0.32833025,0.32637784,0.32589397,0.32401726,0.32475433,0.32815292]
agloss4 = [1.256664,1.0110997,0.77686065,0.6345715,0.55380166,0.49971205,0.4657312,0.43870968,0.4203147,0.4098075,0.39441764,0.39038983,0.38031584,0.37425724,0.36879092,0.36565426,0.36117885,0.36114717,0.35615262,0.3529806,0.3508819,0.34866208,0.3470687,0.34534273,0.34473965,0.34248152,0.34082422,0.34145725,0.3388051,0.3405957]

# %%
import matplotlib.pyplot as plt

fig=plt.figure(figsize=(12, 6), dpi= 80)

# create an index for each tick position
xi = [i for i in range(1, 31)]

# plot the index for the x-values
plt.figure(figsize=(12, 8))
plt.plot(xi, tracc1, marker='o', linestyle='-', label='0')
plt.plot(xi, tracc2, marker='o', linestyle='-', label='0.3')
plt.plot(xi, tracc3, marker='o', linestyle='-', label='0.5')
plt.plot(xi, tracc4, marker='o', linestyle='-', label='0.7')
plt.xlabel('epoch')
plt.ylabel('accuracy') 
plt.xticks(xi)
plt.title('TREC: accuracy vs epoch for comparing dropout rates')
plt.legend(loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt

fig=plt.figure(figsize=(12, 6), dpi= 80)

# create an index for each tick position
xi = [i for i in range(1, 31)]

# plot the index for the x-values
plt.figure(figsize=(12, 8))
plt.plot(xi, trloss1, marker='o', linestyle='-', label='0')
plt.plot(xi, trloss2, marker='o', linestyle='-', label='0.3')
plt.plot(xi, trloss3, marker='o', linestyle='-', label='0.5')
plt.plot(xi, trloss4, marker='o', linestyle='-', label='0.7')
plt.xlabel('epoch')
plt.ylabel('loss') 
plt.xticks(xi)
plt.title('TREC: loss vs epoch for comparing dropout rates')
plt.legend(loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt

fig=plt.figure(figsize=(12, 6), dpi= 80)

# create an index for each tick position
xi = [i for i in range(1, 31)]

# plot the index for the x-values
plt.figure(figsize=(12, 8))
plt.plot(xi, agacc1, marker='o', linestyle='-', label='0')
plt.plot(xi, agacc2, marker='o', linestyle='-', label='0.3')
plt.plot(xi, agacc3, marker='o', linestyle='-', label='0.5')
plt.plot(xi, agacc4, marker='o', linestyle='-', label='0.7')
plt.xlabel('epoch')
plt.ylabel('accuracy') 
plt.xticks(xi)
plt.title('AGNews: accuracy vs epoch for comparing dropout rates')
plt.legend(loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt

fig=plt.figure(figsize=(12, 6), dpi= 80)

# create an index for each tick position
xi = [i for i in range(1, 31)]

# plot the index for the x-values
plt.figure(figsize=(12, 8))
plt.plot(xi, agloss1, marker='o', linestyle='-', label='0')
plt.plot(xi, agloss2, marker='o', linestyle='-', label='0.3')
plt.plot(xi, agloss3, marker='o', linestyle='-', label='0.5')
plt.plot(xi, agloss4, marker='o', linestyle='-', label='0.7')
plt.xlabel('epoch')
plt.ylabel('loss') 
plt.xticks(xi)
plt.title('AGNews: loss vs epoch for comparing dropout rates')
plt.legend(loc='upper left')
plt.show()

# %%
# Filter count/ Number of filters of each type: 3, 6, 9

# dataset 1 (TREC)
# accuracies
tracc1 = [19,53.2,56.4,54.6,57.8,55.4,52.4,54.2,46.2,55.6,55.4,54.2,55.2,61.8,49.2,64.8,58.2,62,64.6,67.6,60.2,57,64.4,63.2,63.2,59,69.6,70.4,62.4,69.6]
tracc2 = [23.6,28.8,54.8,50.4,55.4,64,52.4,63.6,64.2,57.8,63.6,64.6,66,65.8,67.4,60.8,68.4,70.8,69.4,69.2,58.6,65,71.4,71.4,70.6,70.4,69,64,69.8,70.6]
tracc3 = [39.2,41.2,32.6,32.4,32.4,52,56.4,51.2,63.2,61.2,61.2,62.6,63.4,64.4,61.2,62.4,61.6,64,65.6,65.4,68.4,64.2,67,68,65.8,66.6,63.8,66.8,66.4,68.8]
# losses
trloss1 = [1.7030249,1.3806804,1.4001428,1.3079945,1.2627254,1.1936262,1.1029532,1.0970263,1.3125246,1.0767162,1.1289481,1.1136451,1.0890496,1.0541215,1.2211244,0.9895969,1.018601,0.9971646,0.98800176,0.9939811,1.1323527,1.0724778,1.1193131,0.97903955,0.9372447,1.0891718,0.88872695,0.8827002,0.93107283,0.920336]
trloss2 = [1.6382703,1.8017794,1.3255718,1.3193944,1.1493806,1.0957595,1.2567732,0.98146814,0.9881787,1.1683823,1.067882,0.88180023,0.86917454,0.8999046,0.8882252,0.95026815,0.88522816,0.85045534,0.8123237,0.852543,1.0568187,0.9148093,0.78526455,0.7815201,0.81773365,0.77703965,0.8096005,0.9498999,0.7566152,0.8332316]
trloss3 = [1.594621,1.5846835,1.5262676,1.4746106,1.4016831,1.2370074,1.1270168,1.1531682,1.0242181,1.002127,0.98800176,1.0173559,0.9861318,1.0032009,0.91930526,0.9159365,0.953081,0.91509926,0.9691781,0.93381655,0.9178752,0.92411566,0.89306605,0.8453593,0.8170027,0.85886025,0.89898664,0.88982564,0.87734157,0.82620287]

# dataset 2 (AGNews)
# accuracies
agacc1 = [69.6,79.5,83.725,85.975,86.775,87.625,87.725,87.85,88.05,88.5,88.3,88.7,88.675,88.575,88.6,88.85,88.7,88.775,88.825,88.925,88.925,89.05,88.95,89.175,89.175,89.25,89.075,89.2,89.275,89.275]
agacc2 = [80.875,85.675,86.8,87.3,87.85,88.2,88.425,88.425,88.4,88.85,88.75,88.8,89.025,89.225,88.975,89.15,89.125,89.275,89.15,89.2,89.175,89.275,89.225,89.575,89.375,89.725,89.45,89.4,89.6,89.625]
agacc3 = [79.475,84.025,86.125,87.075,87.675,87.925,88.225,88.925,88.8,89.05,89.125,89.2,89.45,89.6,89.525,89.7,89.625,89.625,89.725,89.825,89.925,89.775,89.725,89.75,89.675,89.825,90.075,90,89.7,90.025]
# losses
agloss1 = [1.1288006,0.76297224,0.5559592,0.45928237,0.4088442,0.3830937,0.3658807,0.35626614,0.34979498,0.3423863,0.33997625,0.33449283,0.33294037,0.33100376,0.32755166,0.3263837,0.3244122,0.32282263,0.32330546,0.3213964,0.32091734,0.31878993,0.3182195,0.3166959,0.31616876,0.31582615,0.31799135,0.31553787,0.31529784,0.31460547]
agloss2 = [1.0236996,0.62838244,0.4619556,0.40263385,0.37362215,0.35872933,0.34855792,0.34459826,0.3397115,0.33319324,0.32985705,0.32750252,0.32596996,0.3235726,0.32060224,0.31885055,0.31728148,0.31618464,0.3172055,0.314255,0.31178817,0.3117574,0.31030515,0.30858052,0.3094339,0.3069166,0.30695078,0.30643803,0.30574706,0.30486602]
agloss3 = [1.0343156,0.64519507,0.47545847,0.41149655,0.37499356,0.35742614,0.3461911,0.33808076,0.33367896,0.32780805,0.32511857,0.31944555,0.3165486,0.3154738,0.31197172,0.3103155,0.30821827,0.30773085,0.30657837,0.3051121,0.30212635,0.30049422,0.30231318,0.30082375,0.29947338,0.29801548,0.2961053,0.29540488,0.3003642,0.2946621]

# %%
import matplotlib.pyplot as plt

fig=plt.figure(figsize=(12, 6), dpi= 80)

# create an index for each tick position
xi = [i for i in range(1, 31)]

# plot the index for the x-values
plt.figure(figsize=(12, 8))
plt.plot(xi, tracc1, marker='o', linestyle='-', label='3')
plt.plot(xi, tracc2, marker='o', linestyle='-', label='6')
plt.plot(xi, tracc3, marker='o', linestyle='-', label='9')
plt.xlabel('epoch')
plt.ylabel('accuracy') 
plt.xticks(xi)
plt.title('TREC: accuracy vs epoch for comparing number of filters')
plt.legend(loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt

fig=plt.figure(figsize=(12, 6), dpi= 80)

# create an index for each tick position
xi = [i for i in range(1, 31)]

# plot the index for the x-values
plt.figure(figsize=(12, 8))
plt.plot(xi, trloss1, marker='o', linestyle='-', label='3')
plt.plot(xi, trloss2, marker='o', linestyle='-', label='6')
plt.plot(xi, trloss3, marker='o', linestyle='-', label='9')
plt.xlabel('epoch')
plt.ylabel('loss') 
plt.xticks(xi)
plt.title('TREC: loss vs epoch for comparing number of filters')
plt.legend(loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt

fig=plt.figure(figsize=(12, 6), dpi= 80)

# create an index for each tick position
xi = [i for i in range(1, 31)]

# plot the index for the x-values
plt.figure(figsize=(12, 8))
plt.plot(xi, agacc1, marker='o', linestyle='-', label='3')
plt.plot(xi, agacc2, marker='o', linestyle='-', label='6')
plt.plot(xi, agacc3, marker='o', linestyle='-', label='9')
plt.xlabel('epoch')
plt.ylabel('accuracy') 
plt.xticks(xi)
plt.title('AGNews: accuracy vs epoch for comparing number of filters')
plt.legend(loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt

fig=plt.figure(figsize=(12, 6), dpi= 80)

# create an index for each tick position
xi = [i for i in range(1, 31)]

# plot the index for the x-values
plt.figure(figsize=(12, 8))
plt.plot(xi, agloss1, marker='o', linestyle='-', label='3')
plt.plot(xi, agloss2, marker='o', linestyle='-', label='6')
plt.plot(xi, agloss3, marker='o', linestyle='-', label='9')
plt.xlabel('epoch')
plt.ylabel('loss') 
plt.xticks(xi)
plt.title('AGNews: loss vs epoch for comparing number of filters')
plt.legend(loc='upper left')
plt.show()
