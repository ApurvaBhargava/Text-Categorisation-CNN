agloss2 = [1.1288006,0.76297224,0.5559592,0.45928237,0.4088442,0.3830937,0.3658807,0.35626614,0.34979498,0.3423863,0.33997625,0.33449283,0.33294037,0.33100376,0.32755166,0.3263837,0.3244122,0.32282263,0.32330546,0.3213964,0.32091734,0.31878993,0.3182195,0.3166959,0.31616876,0.31582615,0.31799135,0.31553787,0.31529784,0.31460547]
agloss3 = [1.1747215,0.82162213,0.5812749,0.46915781,0.42001927,0.3960044,0.37839168,0.36825436,0.3565763,0.3499519,0.34850404,0.34503138,0.33859977,0.33476,0.3332411,0.3335715,0.328807,0.32715267,0.32464018,0.32398412,0.32640088,0.32232672,0.32243374,0.32226828,0.31816548,0.31734702,0.31702363,0.31653756,0.315557,0.31631595]

# %%
import matplotlib.pyplot as plt

fig=plt.figure(figsize=(12, 6), dpi= 80)

# create an index for each tick position
xi = [i for i in range(1, 31)]

# plot the index for the x-values
plt.figure(figsize=(12, 8))
plt.plot(xi, tracc1, marker='o', linestyle='-', label='3')
plt.plot(xi, tracc2, marker='o', linestyle='-', label='4')
plt.plot(xi, tracc3, marker='o', linestyle='-', label='5')
plt.xlabel('epoch')
plt.ylabel('accuracy') 
plt.xticks(xi)
plt.title('TREC: accuracy vs epoch for comparing types of filters')
plt.legend(loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt

fig=plt.figure(figsize=(12, 6), dpi= 80)

# create an index for each tick position
xi = [i for i in range(1, 31)]

# plot the index for the x-values
plt.figure(figsize=(12, 8))
plt.plot(xi, trloss1, marker='o', linestyle='-', label='3')
plt.plot(xi, trloss2, marker='o', linestyle='-', label='4')
plt.plot(xi, trloss3, marker='o', linestyle='-', label='5')
plt.xlabel('epoch')
plt.ylabel('loss') 
plt.xticks(xi)
plt.title('TREC: loss vs epoch for comparing types of filters')
plt.legend(loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt

fig=plt.figure(figsize=(12, 6), dpi= 80)

# create an index for each tick position
xi = [i for i in range(1, 31)]

# plot the index for the x-values
plt.figure(figsize=(12, 8))
plt.plot(xi, agacc1, marker='o', linestyle='-', label='3')
plt.plot(xi, agacc2, marker='o', linestyle='-', label='4')
plt.plot(xi, agacc3, marker='o', linestyle='-', label='5')
plt.xlabel('epoch')
plt.ylabel('accuracy') 
plt.xticks(xi)
plt.title('AGNews: accuracy vs epoch for comparing types of filters')
plt.legend(loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt

fig=plt.figure(figsize=(12, 6), dpi= 80)

# create an index for each tick position
xi = [i for i in range(1, 31)]

# plot the index for the x-values
plt.figure(figsize=(12, 8))
plt.plot(xi, agloss1, marker='o', linestyle='-', label='3')
plt.plot(xi, agloss2, marker='o', linestyle='-', label='4')
plt.plot(xi, agloss3, marker='o', linestyle='-', label='5')
plt.xlabel('epoch')
plt.ylabel('loss') 
plt.xticks(xi)
plt.title('AGNews: loss vs epoch for comparing types of filters')
plt.legend(loc='upper left')
plt.show()

# %%
# Features per word in word2vec embedding or dimensionality of embedding: 100, 200, 300

# dataset 1 (TREC)
# accuracies
tracc1 = [19.6,41.6,35.4,51,50,51.8,56.2,56.8,57,55.4,54.4,57.6,57.2,57.4,55.2,57.6,54.2,57.8,52,57,56,59.4,57.8,57.8,53.4,54.6,52.8,52.8,57.8,56.4]
tracc2 = [19,53.2,56.4,54.6,57.8,55.4,52.4,54.2,46.2,55.6,55.4,54.2,55.2,61.8,49.2,64.8,58.2,62,64.6,67.6,60.2,57,64.4,63.2,63.2,59,69.6,70.4,62.4,69.6]
tracc3 = [41.6,50,53.8,50,52.8,53,51,50.8,46,54.2,59.2,60.4,53.4,61,55.6,58.4,57.8,58.2,58.2,55.8,58.8,56.8,65.4,56.8,64.4,61.4,60.6,62,64,63.4]
# losses
trloss1 = [1.6561196,1.4312397,1.5917127,1.307489,1.2479398,1.19659,1.1851721,1.1756747,1.1182654,1.1317922,1.2131678,1.0776494,1.0910244,1.0817865,1.0953557,1.057925,1.0923641,1.0512887,1.1207426,1.0306939,1.0561006,1.0797998,1.0391967,1.0512267,1.1076989,1.0611348,1.090959,1.0413278,1.0516343,1.073237]
trloss2 = [1.7030249,1.3806804,1.4001428,1.3079945,1.2627254,1.1936262,1.1029532,1.0970263,1.3125246,1.0767162,1.1289481,1.1136451,1.0890496,1.0541215,1.2211244,0.9895969,1.018601,0.9971646,0.98800176,0.9939811,1.1323527,1.0724778,1.1193131,0.97903955,0.9372447,1.0891718,0.88872695,0.8827002,0.93107283,0.920336]
trloss3 = [1.5108465,1.4477543,1.3536754,1.2964268,1.1704607,1.244747,1.2354922,1.2012017,1.3510511,1.1469662,1.1761733,1.0776662,1.1839728,1.0661992,1.0798303,1.0523938,1.0533438,1.0403733,1.0402908,1.1971706,1.0545812,1.0810894,1.0463339,1.0259622,1.0595514,0.9707924,0.9740726,0.97682387,1.0738301,0.99175376]

# dataset 2 (AGNews)
# accuracies
agacc1 = [61.825,75.25,81.4,85.075,86.225,86.9,87.3,87.4,87.675,87.95,88.275,88.175,88.375,88.45,88.5,88.5,88.725,88.85,88.825,88.875,88.9,88.95,89.075,88.8,88.95,89.15,89.1,89.075,89.15,89.15]
agacc2 = [69.6,79.5,83.725,85.975,86.775,87.625,87.725,87.85,88.05,88.5,88.3,88.7,88.675,88.575,88.6,88.85,88.7,88.775,88.825,88.925,88.925,89.05,88.95,89.175,89.175,89.25,89.075,89.2,89.275,89.275]
agacc3 = [69.725,83.25,84.575,85.975,86.5,87.05,87.325,87.375,87.925,87.775,88.25,88.475,88.4,88.65,88.45,88.75,88.675,88.7,88.675,89,88.975,88.85,89.125,89.075,89.075,89.325,89.475,89.25,89.3,89.325]
# losses
agloss1 = [1.2563257,0.9535742,0.6684102,0.51234514,0.4341368,0.39785033,0.37813067,0.36495826,0.35577133,0.3490614,0.3435649,0.33961734,0.33843014,0.33517185,0.33039117,0.32848817,0.32858115,0.32581717,0.32308975,0.32248628,0.32135832,0.32008842,0.31976503,0.31785437,0.31697908,0.31860414,0.3165787,0.3160402,0.31485793,0.31375423]
agloss2 = [1.1288006,0.76297224,0.5559592,0.45928237,0.4088442,0.3830937,0.3658807,0.35626614,0.34979498,0.3423863,0.33997625,0.33449283,0.33294037,0.33100376,0.32755166,0.3263837,0.3244122,0.32282263,0.32330546,0.3213964,0.32091734,0.31878993,0.3182195,0.3166959,0.31616876,0.31582615,0.31799135,0.31553787,0.31529784,0.31460547]
agloss3 = [1.2409719,0.9345924,0.6316609,0.48727873,0.42521778,0.39359763,0.3749646,0.36393943,0.3558754,0.35548672,0.3464523,0.34161633,0.33772892,0.33502343,0.33192056,0.32989356,0.32815903,0.32669514,0.32802787,0.32628343,0.3243676,0.32866603,0.3221894,0.32752386,0.32169172,0.32012185,0.3194167,0.31825435,0.3176693,0.31725988]

# %%
import matplotlib.pyplot as plt

fig=plt.figure(figsize=(12, 6), dpi= 80)

# create an index for each tick position
xi = [i for i in range(1, 31)]

# plot the index for the x-values
plt.figure(figsize=(12, 8))
plt.plot(xi, tracc1, marker='o', linestyle='-', label='100')
plt.plot(xi, tracc2, marker='o', linestyle='-', label='200')
plt.plot(xi, tracc3, marker='o', linestyle='-', label='300')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.xticks(xi)
plt.title('TREC: accuracy vs epoch for comparing number of features per word')
plt.legend(loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt

fig=plt.figure(figsize=(12, 6), dpi= 80)

# create an index for each tick position
xi = [i for i in range(1, 31)]

# plot the index for the x-values
plt.figure(figsize=(12, 8))
plt.plot(xi, trloss1, marker='o', linestyle='-', label='100')
plt.plot(xi, trloss2, marker='o', linestyle='-', label='200')
plt.plot(xi, trloss3, marker='o', linestyle='-', label='300')
plt.xlabel('epoch')
plt.ylabel('loss') 
plt.xticks(xi)
plt.title('TREC: loss vs epoch for comparing number of features per word')
plt.legend(loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt

fig=plt.figure(figsize=(12, 6), dpi= 80)

# create an index for each tick position
xi = [i for i in range(1, 31)]

# plot the index for the x-values
plt.figure(figsize=(12, 8))
plt.plot(xi, agacc1, marker='o', linestyle='-', label='100')
plt.plot(xi, agacc2, marker='o', linestyle='-', label='200')
plt.plot(xi, agacc3, marker='o', linestyle='-', label='300')
plt.xlabel('epoch')
plt.ylabel('accuracy') 
plt.xticks(xi)
plt.title('AGNews: accuracy vs epoch for comparing number of features per word')
plt.legend(loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt

fig=plt.figure(figsize=(12, 6), dpi= 80)

# create an index for each tick position
xi = [i for i in range(1, 31)]

# plot the index for the x-values
plt.figure(figsize=(12, 8))
plt.plot(xi, agloss1, marker='o', linestyle='-', label='100')
plt.plot(xi, agloss2, marker='o', linestyle='-', label='200')
plt.plot(xi, agloss3, marker='o', linestyle='-', label='300')
plt.xlabel('epoch')
plt.ylabel('loss') 
plt.xticks(xi)
plt.title('AGNews: loss vs epoch for comparing number of features per word')
plt.legend(loc='upper left')
plt.show()
